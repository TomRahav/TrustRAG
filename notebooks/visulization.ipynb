# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv("extracted_log_data.csv")

# Display the first few rows
df.head()
# Out:
#   dataset       model score       attack adv_a_position removal  no_questions  \
# 0     NaN         NaN   NaN          NaN            NaN     NaN             0
# 1     NaN         NaN   NaN          NaN            NaN     NaN             0
# 2      nq  contriever   dot  LM_targeted          start   drift             1
# 3      nq  contriever   dot      hotflip          start   drift             1
# 4      nq  contriever   dot      hotflip            end   drift             1
#
#   defense  adv_per_query     M  repeat  total_topk_num  total_adv_num  \
# 0     NaN            NaN   NaN     NaN             NaN            NaN
# 1     NaN            NaN   NaN     NaN            50.0           30.0
# 2    none            3.0  10.0    10.0           500.0          300.0
# 3    none            3.0  10.0    10.0           500.0          300.0
# 4    none            3.0  10.0    10.0           500.0          300.0
#
#   success_injection_rate  llm_model  inference_time correct_answer_pct  \
# ...

# %%
print("---------- Dataframe Info ----------")
df.info()
print("---------- Dataframe Describe ----------")
df.describe()
# Out:
# ---------- Dataframe Info ----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   dataset                 26 non-null     object
#  1   model                   26 non-null     object
#  2   score                   26 non-null     object
#  3   attack                  26 non-null     object
#  4   adv_a_position          26 non-null     object
#  5   removal                 26 non-null     object
#  6   no_questions            28 non-null     int64
#  7   defense                 26 non-null     object
#  8   adv_per_query           26 non-null     float64
#  9   M                       26 non-null     float64
#  10  repeat                  26 non-null     float64
#  11  total_topk_num          19 non-null     float64
#  12  total_adv_num           19 non-null     float64
# ...

# %%
df[(df["model"] == "contriever") & (df["attack"] == "hotflip")]
